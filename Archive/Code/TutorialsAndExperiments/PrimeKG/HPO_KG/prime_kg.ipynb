# %%
import pandas as pd
# link to datasets to download
#https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/IXA7BM
kg = pd.read_csv('import/kg.csv', low_memory=False)
nodes = pd.read_csv('import/nodes.csv', low_memory=False)
drug_features = pd.read_csv('import/drug_features.csv', low_memory=False)
disease_features = pd.read_csv('import/disease_features.csv', low_memory=False)

# %%
print(kg.columns.tolist())
print(nodes.columns.tolist())
print(drug_features.columns.tolist())
print(disease_features.columns.tolist())
# Out:
# ['relation', 'display_relation', 'x_index', 'x_id', 'x_type', 'x_name', 'x_source', 'y_index', 'y_id', 'y_type', 'y_name', 'y_source']
# ['node_index', 'node_id', 'node_type', 'node_name', 'node_source']
# ['node_index', 'description', 'half_life', 'indication', 'mechanism_of_action', 'protein_binding', 'pharmacodynamics', 'state', 'atc_1', 'atc_2', 'atc_3', 'atc_4', 'category', 'group', 'pathway', 'molecular_weight', 'tpsa', 'clogp']
# ['node_index', 'mondo_id', 'mondo_name', 'group_id_bert', 'group_name_bert', 'mondo_definition', 'umls_description', 'orphanet_definition', 'orphanet_prevalence', 'orphanet_epidemiology', 'orphanet_clinical_description', 'orphanet_management_and_treatment', 'mayo_symptoms', 'mayo_causes', 'mayo_risk_factors', 'mayo_complications', 'mayo_prevention', 'mayo_see_doc']

# %% [markdown]
# #### KG
# - **relation**: The technical name of the link (e.g., indication, off-label use).
# - **display_relation**: The human-readable version (e.g., "treats", "causes side effect").
# - **x_index / y_index**: The unique numerical IDs for the two entities being linked.
# - **x_id / y_id**: The external database IDs (e.g., a DrugBank ID or a Mondo ID).
# - **x_type / y_type**: What kind of things they are (e.g., drug, disease, phenotype).
# - **x_name / y_name**: The common names (e.g., "Aspirin", "Headache").
# - **x_source / y_source** : Where this specific link was discovered (e.g., DrugBank, CTD).
# #### Nodes
# - **node_index** : The primary key used to link to the other files.
# - **node_id**: The official medical code (HPO, MONDO, etc.).
# - **node_type**: The category (Drug, Disease, etc.).
# - **node_name**: The official name of the concept.
# - **node_source**: The vocabulary source (e.g., MSH for MeSH).
# #### drug_features
# - **description**: A general overview of the drug.
# - **half_life** : How long the drug stays in the body (critical for dosage reasoning).
# - **indication** : The specific medical condition the drug is approved to treat.
# - **mechanism_of_action** : (CRITICAL) The biological "how"—which receptors it hits.
# - **protein_binding** : How the drug hitches a ride in the blood.
# - **pharmacodynamics** : The effect the drug has on the body.
# - **state** : Physical state (Solid, Liquid, etc.).
# - **atc_1 through atc_4** : Anatomical Therapeutic Chemical classification (a hierarchy of what organ system the drug targets).
# - **category / group** : Labels like "Analgesic" or "Approved".
# - **pathway**: The biological "road" the drug travels in the cell.
# - **molecular_weight / tpsa / clogp**: Chemical properties (less relevant for diagnosis, more for drug discovery).
#
# #### disease_features
# - **mondo_id / mondo_name** : Official identifier and name in the Mondo Disease Ontology.
#
# - **group_id_bert / group_name_bert**: AI-clustered disease groups (useful for machine learning tasks).
#
# - **mondo_definition**: (CRITICAL) The textbook definition of the disease.
#
# - **umls_description**: A secondary description from the Unified Medical Language System.
#
# - **orphanet_definition / epidemiology / clinical_description**: Deep data for rare diseases (Orphanet focus).
#
# - **orphanet_prevalence**: How common the disease is (essential for calculating probability).
#
# - **mayo_symptoms**: (CRITICAL for DDXPlus) A list of symptoms used to diagnose the disease.
#
# - **mayo_causes**: What triggers the disease (environmental, genetic, etc.).
#
# - **mayo_risk_factors / complications**: What makes the disease worse and what it can lead to.
#
# - **mayo_prevention**: How to avoid it.
#
# - **mayo_see_doc**: "Red flag" signs that mean the patient needs an emergency room.

# %%
kg.columns = [c.strip() for c in kg.columns]
drug_features.columns = [c.strip() for c in drug_features.columns]
disease_features.columns = [c.strip() for c in disease_features.columns]

# %%
## drop duplicates is done for having unique (relation, display_relation) pairs, and sort_values is for better readability
mapping = kg[['relation', 'display_relation']].drop_duplicates().sort_values('relation')
relation_counts = kg['relation'].value_counts() #it creates new  series "unique relation- number of row for that relation"
print("number of relation types: ",len(relation_counts))
print(mapping)
# Out:
# number of relation types:  30
#                            relation         display_relation
# 3834678             anatomy_anatomy             parent-child
# 5366913      anatomy_protein_absent        expression absent
# 3848710     anatomy_protein_present       expression present
# 3413119       bioprocess_bioprocess             parent-child
# 3637356          bioprocess_protein           interacts with
# 3479579           cellcomp_cellcomp             parent-child
# 3553954            cellcomp_protein           interacts with
# 346728             contraindication         contraindication
# 3315993             disease_disease             parent-child
# 3084053  disease_phenotype_negative         phenotype absent
# 3085246  disease_phenotype_positive        phenotype present
# 3235582             disease_protein          associated with
# 389359                    drug_drug  synergistic interaction
# 3348335                 drug_effect              side effect
# 321075                 drug_protein                  carrier
# 327256                 drug_protein                   target
# 343636                 drug_protein              transporter
# 321939                 drug_protein                   enzyme
# 3787817         exposure_bioprocess           interacts with
# 3789487           exposure_cellcomp           interacts with
# 3783373            exposure_disease                linked to
# 3785677           exposure_exposure             parent-child
# 3789442            exposure_molfunc           interacts with
# 3782161            exposure_protein           interacts with
# 346730                   indication               indication
# 3466005             molfunc_molfunc             parent-child
# 3484424             molfunc_protein           interacts with
# 347016                off-label use            off-label use
# 3789497             pathway_pathway             parent-child
# 3792032             pathway_protein           interacts with
# 3065317         phenotype_phenotype             parent-child
# 3061987           phenotype_protein          associated with
# 0                   protein_protein                      ppi

# %%
examples = kg[['x_name', 'x_type', 'display_relation', 'y_name', 'y_type', 'relation']].drop_duplicates(subset=['relation'])

examples = examples.sort_values('relation')

print("Relationship Examples (Node [Type] -> Edge -> Node [Type]):")
print("-" * 80)

for index, row in examples.iterrows():
    source = f"{row['x_name']} ({row['x_type']})"
    edge = row['display_relation']
    target = f"{row['y_name']} ({row['y_type']})"
    
    print(f"[{source}] --({edge})--> [{target}]")
# Out:
# Relationship Examples (Node [Type] -> Edge -> Node [Type]):
# --------------------------------------------------------------------------------
# [uterine cervix (anatomy)] --(parent-child)--> [reproductive structure (anatomy)]
# [FGR (gene/protein)] --(expression absent)--> [deltoid (anatomy)]
# [TSPAN6 (gene/protein)] --(expression present)--> [uterine cervix (anatomy)]
# [negative regulation of neurotransmitter uptake (biological_process)] --(parent-child)--> [negative regulation of serotonin uptake (biological_process)]
# [A1BG (gene/protein)] --(interacts with)--> [neutrophil degranulation (biological_process)]
# [cellular anatomical entity (cellular_component)] --(parent-child)--> [unicellular trichome tip (cellular_component)]
# [A1BG (gene/protein)] --(interacts with)--> [ficolin-1-rich granule lumen (cellular_component)]
# [Rotigotine (drug)] --(contraindication)--> [hypertensive disorder (disease)]
# [adrenal cortex disease (disease)] --(parent-child)--> [adrenocortical insufficiency (disease)]
# [osteogenesis imperfecta (disease)] --(phenotype absent)--> [Hearing impairment (effect/phenotype)]
# [retinitis pigmentosa (disease)] --(phenotype present)--> [Rod-cone dystrophy (effect/phenotype)]
# [A1BG (gene/protein)] --(associated with)--> [schizophrenia (disease)]
# [Lepirudin (drug)] --(synergistic interaction)--> [Apixaban (drug)]
# [Levocarnitine (drug)] --(side effect)--> [Abdominal pain (effect/phenotype)]
# [Copper (drug)] --(carrier)--> [F8 (gene/protein)]
# [1,2,3,4,6,7,8-heptachlorodibenzodioxin (exposure)] --(interacts with)--> [regulation of blood pressure (biological_process)]
# [Air Pollutants (exposure)] --(interacts with)--> [IgE immunoglobulin complex, circulating (cellular_component)]
# [1,1,1-trichloroethane (exposure)] --(linked to)--> [amyotrophic lateral sclerosis (disease)]
# [1-naphthol (exposure)] --(parent-child)--> [2-naphthol (exposure)]
# [2,4,5,2',4',5'-hexachlorobiphenyl (exposure)] --(interacts with)--> [IgA receptor activity (molecular_function)]
# [1-hydroxyphenanthrene (exposure)] --(interacts with)--> [CRP (gene/protein)]
# [Fosinopril (drug)] --(indication)--> [hypertensive disorder (disease)]
# [methyltransferase activity (molecular_function)] --(parent-child)--> [malonyl-CoA methyltransferase activity (molecular_function)]
# [A2M (gene/protein)] --(interacts with)--> [interleukin-1 binding (molecular_function)]
# [Etacrynic acid (drug)] --(off-label use)--> [hypertensive disorder (disease)]
# [Apoptosis (pathway)] --(parent-child)--> [Intrinsic Pathway for Apoptosis (pathway)]
# [A1BG (gene/protein)] --(interacts with)--> [Platelet degranulation  (pathway)]
# [Growth abnormality (effect/phenotype)] --(parent-child)--> [Abnormality of body height (effect/phenotype)]
# [A1BG (gene/protein)] --(associated with)--> [Hepatomegaly (effect/phenotype)]
# [PHYHIP (gene/protein)] --(ppi)--> [KIF15 (gene/protein)]

# %%
examples = nodes.groupby('node_type').first().reset_index()

print(f"{'NODE TYPE':<25} | {'EXAMPLE NAME (node_name)'}")
print("-" * 60)

for _, row in examples.iterrows():
    print(f"{row['node_type']:<25} | {row['node_name']}")
# Out:
# NODE TYPE                 | EXAMPLE NAME (node_name)
# ------------------------------------------------------------
# anatomy                   | uterine cervix
# biological_process        | negative regulation of neurotransmitter uptake
# cellular_component        | cellular anatomical entity
# disease                   | osteogenesis imperfecta
# drug                      | Copper
# effect/phenotype          | Growth abnormality
# exposure                  | 1-hydroxyphenanthrene
# gene/protein              | PHYHIP
# molecular_function        | methyltransferase activity
# pathway                   | Apoptosis

# %%
clinical_relations = ['disease_phenotype_positive', 'indication', 'contraindication']
filtered_df = kg[kg['relation'].isin(clinical_relations)].copy()

# %%
nodes_map = filtered_df[['relation', 'x_type', 'y_type']].drop_duplicates().reset_index(drop=True)
print("--- Clinical Relationship Node Map ---")
print(nodes_map)

print("\n--- Connection Type Counts ---")
counts = filtered_df.groupby(['relation', 'x_type', 'y_type']).size().reset_index(name='count')
print(counts)
# Out:
# --- Clinical Relationship Node Map ---
#                      relation            x_type            y_type
# 0            contraindication              drug           disease
# 1                  indication              drug           disease
# 2  disease_phenotype_positive           disease  effect/phenotype
# 3  disease_phenotype_positive  effect/phenotype           disease
# 4            contraindication           disease              drug
# 5                  indication           disease              drug
#
# --- Connection Type Counts ---
#                      relation            x_type            y_type   count
# 0            contraindication           disease              drug   30675
# 1            contraindication              drug           disease   30675
# 2  disease_phenotype_positive           disease  effect/phenotype  150317
# 3  disease_phenotype_positive  effect/phenotype           disease  150317
# 4                  indication           disease              drug    9388
# 5                  indication              drug           disease    9388

# %%
# take x_index from the KG, take  node_index from the drug features to 
enriched = pd.merge(
    filtered_df, 
    drug_features[['node_index', 'mechanism_of_action', 'description']], 
    left_on='x_index', 
    right_on='node_index', 
    how='left'
).rename(columns={'mechanism_of_action': 'x_mechanism', 'description': 'x_description'}).drop(columns=['node_index'])

# %%
# take y_index from the KG, take  node_index from the drug features to 
enriched = pd.merge(
    enriched, 
    drug_features[['node_index', 'mechanism_of_action', 'description']], 
    left_on='y_index', 
    right_on='node_index', 
    how='left'
).rename(columns={'mechanism_of_action': 'y_mechanism', 'description': 'y_description'}).drop(columns=['node_index'])

# %%
enriched = pd.merge(
    enriched, 
    disease_features[['node_index', 'mondo_definition', 'mayo_symptoms']], 
    left_on='x_index', 
    right_on='node_index', 
    how='left'
).rename(columns={'mondo_definition': 'x_definition', 'mayo_symptoms': 'x_symptoms'}).drop(columns=['node_index'])

# %%
enriched = pd.merge(
    enriched, 
    disease_features[['node_index', 'mondo_definition', 'mayo_symptoms']], 
    left_on='y_index', 
    right_on='node_index', 
    how='left'
).rename(columns={'mondo_definition': 'y_definition', 'mayo_symptoms': 'y_symptoms'}).drop(columns=['node_index'])

# %%
display_table = enriched[[
    'x_name', 
    'relation', 
    'y_name', 
    'x_mechanism', 
    "x_definition",
    "y_mechanism",
    'y_definition'
]].drop_duplicates().head(10).fillna('N/A')

pd.set_option('display.max_colwidth', None)
display_table
# Out:
#         x_name          relation                 y_name  \
# 0   Rotigotine  contraindication  hypertensive disorder
# 13  Rotigotine  contraindication           hypertension
# 15  Rotigotine  contraindication           hypertension
# 27  Rotigotine  contraindication           hypertension
# 28  Rotigotine  contraindication           hypertension
# 36  Rotigotine  contraindication           hypertension
# 37  Fosinopril        indication  hypertensive disorder
# 50  Fosinopril        indication           hypertension
# 52  Fosinopril        indication           hypertension
# 64  Fosinopril        indication           hypertension
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        x_mechanism  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Rotigotine, a member of the dopamine agonist class of drugs, is delivered continuously through the skin (transdermal) using a silicone-based patch that is replaced every 24 hours. A dopamine agonist works by activating dopamine receptors in the body, mimicking the effect of the neurotransmitter dopamine. The precise mechanism of action of rotigotine as a treatment for Restless Legs Syndrome is unknown but is thought to be related to its ability to stimulate dopamine
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Rotigotine, a member of the dopamine agonist class of drugs, is delivered continuously through the skin (transdermal) using a silicone-based patch that is replaced every 24 hours. A dopamine agonist works by activating dopamine receptors in the body, mimicking the effect of the neurotransmitter dopamine. The precise mechanism of action of rotigotine as a treatment for Restless Legs Syndrome is unknown but is thought to be related to its ability to stimulate dopamine
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Rotigotine, a member of the dopamine agonist class of drugs, is delivered continuously through the skin (transdermal) using a silicone-based patch that is replaced every 24 hours. A dopamine agonist works by activating dopamine receptors in the body, mimicking the effect of the neurotransmitter dopamine. The precise mechanism of action of rotigotine as a treatment for Restless Legs Syndrome is unknown but is thought to be related to its ability to stimulate dopamine
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Rotigotine, a member of the dopamine agonist class of drugs, is delivered continuously through the skin (transdermal) using a silicone-based patch that is replaced every 24 hours. A dopamine agonist works by activating dopamine receptors in the body, mimicking the effect of the neurotransmitter dopamine. The precise mechanism of action of rotigotine as a treatment for Restless Legs Syndrome is unknown but is thought to be related to its ability to stimulate dopamine
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Rotigotine, a member of the dopamine agonist class of drugs, is delivered continuously through the skin (transdermal) using a silicone-based patch that is replaced every 24 hours. A dopamine agonist works by activating dopamine receptors in the body, mimicking the effect of the neurotransmitter dopamine. The precise mechanism of action of rotigotine as a treatment for Restless Legs Syndrome is unknown but is thought to be related to its ability to stimulate dopamine
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Rotigotine, a member of the dopamine agonist class of drugs, is delivered continuously through the skin (transdermal) using a silicone-based patch that is replaced every 24 hours. A dopamine agonist works by activating dopamine receptors in the body, mimicking the effect of the neurotransmitter dopamine. The precise mechanism of action of rotigotine as a treatment for Restless Legs Syndrome is unknown but is thought to be related to its ability to stimulate dopamine
# 37  There are two isoforms of ACE: the somatic isoform, which exists as a glycoprotein comprised of a single polypeptide chain of 1277; and the testicular isoform, which has a lower molecular mass and is thought to play a role in sperm maturation and binding of sperm to the oviduct epithelium. Somatic ACE has two functionally active domains, N and C, which arise from tandem gene duplication. Although the two domains have high sequence similarity, they play distinct physiological roles. The C-domain is predominantly involved in blood pressure regulation while the N-domain plays a role in hematopoietic stem cell differentiation and proliferation. ACE inhibitors bind to and inhibit the activity of both domains, but have much greater affinity for and inhibitory activity against the C-domain. Fosinoprilat, the active metabolite of fosinopril, competes with ATI for binding to ACE and inhibits and enzymatic proteolysis of ATI to ATII. Decreasing ATII levels in the body decreases blood pressure by inhibiting the pressor effects of ATII as described in the Pharmacology section above. Fosinoprilat also causes an increase in plasma renin activity likely due to a loss of feedback inhibition mediated by ATII on the release of renin and/or stimulation of reflex mechanisms via baroreceptors.
# 50  There are two isoforms of ACE: the somatic isoform, which exists as a glycoprotein comprised of a single polypeptide chain of 1277; and the testicular isoform, which has a lower molecular mass and is thought to play a role in sperm maturation and binding of sperm to the oviduct epithelium. Somatic ACE has two functionally active domains, N and C, which arise from tandem gene duplication. Although the two domains have high sequence similarity, they play distinct physiological roles. The C-domain is predominantly involved in blood pressure regulation while the N-domain plays a role in hematopoietic stem cell differentiation and proliferation. ACE inhibitors bind to and inhibit the activity of both domains, but have much greater affinity for and inhibitory activity against the C-domain. Fosinoprilat, the active metabolite of fosinopril, competes with ATI for binding to ACE and inhibits and enzymatic proteolysis of ATI to ATII. Decreasing ATII levels in the body decreases blood pressure by inhibiting the pressor effects of ATII as described in the Pharmacology section above. Fosinoprilat also causes an increase in plasma renin activity likely due to a loss of feedback inhibition mediated by ATII on the release of renin and/or stimulation of reflex mechanisms via baroreceptors.
# 52  There are two isoforms of ACE: the somatic isoform, which exists as a glycoprotein comprised of a single polypeptide chain of 1277; and the testicular isoform, which has a lower molecular mass and is thought to play a role in sperm maturation and binding of sperm to the oviduct epithelium. Somatic ACE has two functionally active domains, N and C, which arise from tandem gene duplication. Although the two domains have high sequence similarity, they play distinct physiological roles. The C-domain is predominantly involved in blood pressure regulation while the N-domain plays a role in hematopoietic stem cell differentiation and proliferation. ACE inhibitors bind to and inhibit the activity of both domains, but have much greater affinity for and inhibitory activity against the C-domain. Fosinoprilat, the active metabolite of fosinopril, competes with ATI for binding to ACE and inhibits and enzymatic proteolysis of ATI to ATII. Decreasing ATII levels in the body decreases blood pressure by inhibiting the pressor effects of ATII as described in the Pharmacology section above. Fosinoprilat also causes an increase in plasma renin activity likely due to a loss of feedback inhibition mediated by ATII on the release of renin and/or stimulation of reflex mechanisms via baroreceptors.
# 64  There are two isoforms of ACE: the somatic isoform, which exists as a glycoprotein comprised of a single polypeptide chain of 1277; and the testicular isoform, which has a lower molecular mass and is thought to play a role in sperm maturation and binding of sperm to the oviduct epithelium. Somatic ACE has two functionally active domains, N and C, which arise from tandem gene duplication. Although the two domains have high sequence similarity, they play distinct physiological roles. The C-domain is predominantly involved in blood pressure regulation while the N-domain plays a role in hematopoietic stem cell differentiation and proliferation. ACE inhibitors bind to and inhibit the activity of both domains, but have much greater affinity for and inhibitory activity against the C-domain. Fosinoprilat, the active metabolite of fosinopril, competes with ATI for binding to ACE and inhibits and enzymatic proteolysis of ATI to ATII. Decreasing ATII levels in the body decreases blood pressure by inhibiting the pressor effects of ATII as described in the Pharmacology section above. Fosinoprilat also causes an increase in plasma renin activity likely due to a loss of feedback inhibition mediated by ATII on the release of renin and/or stimulation of reflex mechanisms via baroreceptors.
#
#    x_definition y_mechanism  \
# 0           N/A         N/A
# 13          N/A         N/A
# 15          N/A         N/A
# 27          N/A         N/A
# 28          N/A         N/A
# 36          N/A         N/A
# 37          N/A         N/A
# 50          N/A         N/A
# 52          N/A         N/A
# 64          N/A         N/A
#
#                                                                                                                                                                                                                                                                        y_definition
# 0    Persistently high systemic arterial blood pressure. Based on multiple readings (blood pressure determination), hypertension is currently defined as when systolic pressure is consistently greater than 140 mm Hg or when diastolic pressure is consistently 90 mm Hg or more.
# 13                                                                                                                                                                                                                   High blood pressure caused by an underlying medical condition.
# 15                                                                                                                                                                                                                        Hypertension that presents without an identifiable cause.
# 27                                                                                                                                                                                         An instance of hypertension that is caused by a modification of the individual's genome.
# 28  Increased blood pressure in the portal venous system. It is most commonly caused by cirrhosis. Other causes include portal vein thrombosis, Budd-Chiari syndrome, and right heart failure. Complications include ascites, esophageal varices, encephalopathy, and splenomegaly.
# 36                                                                                        A severe medical condition which is estimated to appear in 9-18% of hypertensive patients, in which treatement with 3 or more antihypertensive drugs including diuretics are ineffective.
# 37   Persistently high systemic arterial blood pressure. Based on multiple readings (blood pressure determination), hypertension is currently defined as when systolic pressure is consistently greater than 140 mm Hg or when diastolic pressure is consistently 90 mm Hg or more.
# 50                                                                                                                                                                                                                   High blood pressure caused by an underlying medical condition.
# 52                                                                                                                                                                                                                        Hypertension that presents without an identifiable cause.
# 64                                                                                                                                                                                         An instance of hypertension that is caused by a modification of the individual's genome.

# %%
drug_nodes = nodes[nodes['node_type'] == 'drug']
disease_nodes = nodes[nodes['node_type'] == 'disease']
print(f"Drug nodes: {len(drug_nodes)}, with features: {drug_nodes['node_index'].isin(drug_features['node_index']).sum()}")
print(f"Disease nodes: {len(disease_nodes)}, with features: {disease_nodes['node_index'].isin(disease_features['node_index']).sum()}")
# Out:
# Drug nodes: 7957, with features: 7957
# Disease nodes: 17080, with features: 17080

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all_diseases = nodes[nodes['node_type'] == 'disease']['node_index'].unique()
total_disease_count = len(all_diseases)

indications = kg[kg['relation'] == 'indication']
counts_per_disease = indications.groupby('y_index')['x_index'].nunique()

full_distribution = pd.Series(0, index=all_diseases)
full_distribution.update(counts_per_disease)

def categorize_indications(count):
    if count >= 12:
        return "12+"
    else:
        return str(int(count))

plot_data = full_distribution.apply(categorize_indications).value_counts().reset_index()
plot_data.columns = ['Indications', 'Disease_Count']

order = [str(i) for i in range(12)] + ["12+"]
plot_data['Indications'] = pd.Categorical(plot_data['Indications'], categories=order, ordered=True)
plot_data = plot_data.sort_values('Indications')

plt.figure(figsize=(14, 7))
ax = sns.barplot(x='Indications', y='Disease_Count', data=plot_data, palette='viridis')

plt.title('How Many Drugs are Approved per Disease? (PrimeKG Distribution)', fontsize=16, pad=20)
plt.xlabel('Exact Number of Approved Drug Indications', fontsize=12)
plt.ylabel('Number of Diseases', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.4)

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 9), 
                textcoords='offset points',
                fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

print(f"Summary Statistics:")
print(f"- Total Diseases in PrimeKG: {total_disease_count}")
print(f"- Diseases with 0 treatments: {int(plot_data[plot_data['Indications'] == '0']['Disease_Count'].values[0])}")
print(f"- Percentage of diseases with no treatment: {(int(plot_data[plot_data['Indications'] == '0']['Disease_Count'].values[0]) / total_disease_count) * 100:.2f}%")
# Out:
# C:\Users\Cengizhan\AppData\Local\Temp\ipykernel_22104\2099740942.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Indications', y='Disease_Count', data=plot_data, palette='viridis')
# Summary Statistics:
# - Total Diseases in PrimeKG: 17080
# - Diseases with 0 treatments: 15717
# - Percentage of diseases with no treatment: 92.02%

# %%
all_diseases = nodes[nodes['node_type'] == 'disease']['node_index'].unique()
total_disease_count = len(all_diseases)

treatment_relations = ['indication', 'off-label use']
treatments = kg[kg['relation'].isin(treatment_relations)]


counts_per_disease = treatments.groupby('y_index')['x_index'].nunique()

full_distribution = pd.Series(0, index=all_diseases)
full_distribution.update(counts_per_disease)



plot_data = full_distribution.apply(categorize).value_counts().reset_index()
plot_data.columns = ['Drug_Count', 'Disease_Count']

order = [str(i) for i in range(12)] + ["12+"]
plot_data['Drug_Count'] = pd.Categorical(plot_data['Drug_Count'], categories=order, ordered=True)
plot_data = plot_data.sort_values('Drug_Count')

plt.figure(figsize=(14, 7))
ax = sns.barplot(x='Drug_Count', y='Disease_Count', data=plot_data, palette='magma')

plt.title('Combined Therapeutic Distribution: Indication + Off-Label Use (PrimeKG)', fontsize=16, pad=20)
plt.xlabel('Total Number of Unique Drugs (Approved or Off-Label)', fontsize=12)
plt.ylabel('Number of Diseases', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.3)

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 9), 
                textcoords='offset points',
                fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

diseases_with_treatment = (full_distribution > 0).sum()
print(f"Total Unique Diseases: {total_disease_count}")
print(f"Diseases with at least 1 drug (Indication or Off-label): {diseases_with_treatment}")
print(f"Remaining 'Orphan' Diseases (0 drugs): {total_disease_count - diseases_with_treatment}")
print(f"- Percentage of diseases with no treatment: {(int(plot_data[plot_data['Drug_Count'] == '0']['Disease_Count'].values[0]) / total_disease_count) * 100:.2f}%")
# Out:
# C:\Users\Cengizhan\AppData\Local\Temp\ipykernel_22104\2511395320.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Drug_Count', y='Disease_Count', data=plot_data, palette='magma')
# Total Unique Diseases: 17080
# Diseases with at least 1 drug (Indication or Off-label): 1548
# Remaining 'Orphan' Diseases (0 drugs): 15532
# - Percentage of diseases with no treatment: 90.94%
