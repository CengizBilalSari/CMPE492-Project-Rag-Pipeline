# %%
import os
import asyncio
from openai import AsyncOpenAI
from ragas.llms import llm_factory
from ragas.embeddings import HuggingFaceEmbeddings
from langchain_community.document_loaders import DirectoryLoader
from ragas.testset import TestsetGenerator

# %%
import logging
from ragas.testset.transforms.extractors.llm_based import HeadlinesExtractor, SummaryExtractor, KeyphrasesExtractor
from ragas.testset.transforms.splitters import HeadlineSplitter

logging.getLogger("ragas.prompt").setLevel(logging.DEBUG)
logging.getLogger("ragas.llms").setLevel(logging.DEBUG)

logging.basicConfig(level=logging.INFO)
async def generate_testset():
    # Ollama's OpenAI-compatible endpoint 
    async_client = AsyncOpenAI(
        base_url="http://localhost:11434/v1",
        api_key="ollama"  # dummy api key
    )

    generator_llm = llm_factory("qwen2.5:3b", client=async_client, provider="openai")

    generator_embeddings = HuggingFaceEmbeddings(model="BAAI/bge-small-en-v1.5")

    loader = DirectoryLoader("../../Documents/Ragas", glob="**/*.pdf")    
    documents = loader.load()
    
    for doc in documents:
        doc.metadata['filename'] = doc.metadata.get('source', 'unknown')

    generator = TestsetGenerator(
        llm=generator_llm,
        embedding_model=generator_embeddings
    )
    my_splitter = HeadlineSplitter(min_tokens=100, max_tokens=500)
    my_headlines = HeadlinesExtractor(llm=generator_llm, max_token_limit=300)
    my_summary = SummaryExtractor(llm=generator_llm, max_token_limit=300)
    my_keys = KeyphrasesExtractor(llm=generator_llm, max_token_limit=2000)

    testset = generator.generate_with_langchain_docs(
        documents=documents,
        testset_size=8,
        transforms=[my_splitter,my_headlines, my_summary, my_keys] # Include all three
    )

    df = testset.to_pandas()
    print(df.head())
    df.to_csv("testset_qwen.csv", index=False)

await generate_testset()
# Out:
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cpu
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: BAAI/bge-small-en-v1.5
# Warning: No languages specified, defaulting to English.
# Applying HeadlineSplitter:   0%|          | 0/1 [00:00<?, ?it/s]
# ERROR:ragas.async_utils:Task failed with ValueError: 'headlines' property not found in this node
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 46
#      43     print(df.head())
#      44     df.to_csv("testset_qwen.csv", index=False)
# ---> 46 await generate_testset()
#
# Cell In[5], line 36, in generate_testset()
#      33 my_summary = SummaryExtractor(llm=generator_llm, max_token_limit=300)
#      34 my_keys = KeyphrasesExtractor(llm=generator_llm, max_token_limit=2000)
# ---> 36 testset = generator.generate_with_langchain_docs(
#      37     documents=documents,
#      38     testset_size=8,
#      39     transforms=[my_splitter,my_headlines, my_summary, my_keys] # Include all three
#      40 )
#      42 df = testset.to_pandas()
#      43 print(df.head())
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\ragas\testset\synthesizers\generate.py:208, in TestsetGenerator.generate_with_langchain_docs(self, documents, testset_size, transforms, transforms_llm, transforms_embedding_model, query_distribution, run_config, callbacks, token_usage_parser, with_debugging_logs, raise_exceptions, return_executor)
#     205 kg = KnowledgeGraph(nodes=nodes)
#     207 # apply transforms and update the knowledge graph
# --> 208 apply_transforms(kg, transforms, run_config=run_config or RunConfig())
#     209 self.knowledge_graph = kg
#     211 return self.generate(
#     212     testset_size=testset_size,
#     213     query_distribution=query_distribution,
#    (...)    219     return_executor=return_executor,
#     220 )
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\ragas\testset\transforms\engine.py:70, in apply_transforms(kg, transforms, run_config, callbacks)
#      68 if isinstance(transforms, t.Sequence):
#      69     for transform in transforms:
# ---> 70         apply_transforms(kg, transform, run_config, callbacks)
#      71 elif isinstance(transforms, Parallel):
#      72     apply_transforms(kg, transforms.transformations, run_config, callbacks)
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\ragas\testset\transforms\engine.py:79, in apply_transforms(kg, transforms, run_config, callbacks)
#      77     coros = transforms.generate_execution_plan(kg)
#      78     desc = get_desc(transforms)
# ---> 79     run_async_tasks(
#      80         coros,
#      81         batch_size=None,
#      82         show_progress=True,
#      83         progress_bar_desc=desc,
#      84         max_workers=max_workers,
#      85     )
#      86 else:
#      87     raise ValueError(
#      88         f"Invalid transforms type: {type(transforms)}. Expects a sequence of BaseGraphTransformations or a Parallel instance."
#      89     )
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\ragas\async_utils.py:232, in run_async_tasks(tasks, batch_size, show_progress, progress_bar_desc, max_workers, cancel_check)
#     228         raise first_exception
#     230     return results
# --> 232 return run(_run)
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\ragas\async_utils.py:156, in run(async_func, allow_nest_asyncio)
#     148     loop_type = type(loop).__name__
#     149     raise RuntimeError(
#     150         f"Cannot execute nested async code with {loop_type}. "
#     151         f"uvloop does not support nested event loop execution. "
#     152         f"Please use asyncio's standard event loop in Jupyter environments, "
#     153         f"or refactor your code to avoid nested async calls."
#     154     )
# --> 156 return asyncio.run(coro)
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\ragas\async_utils.py:228, in run_async_tasks.<locals>._run()
#     226 # Raise the first exception encountered to fail fast with clear error message
#     227 if first_exception is not None:
# --> 228     raise first_exception
#     230 return results
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\ragas\async_utils.py:114, in process_futures(futures)
#     112 for future in futures:
#     113     try:
# --> 114         result = await future
#     115     except asyncio.CancelledError:
#     116         raise  # Re-raise CancelledError to ensure proper cancellation
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:634, in _AsCompletedIterator._wait_for_one(self, resolve)
#     631 if f is None:
#     632     # Dummy value from _handle_timeout().
#     633     raise exceptions.TimeoutError
# --> 634 return f.result() if resolve else f
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\ragas\async_utils.py:77, in as_completed.<locals>.sema_coro(coro)
#      75 async def sema_coro(coro):
#      76     async with semaphore:
# ---> 77         return await coro
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\ragas\testset\transforms\base.py:310, in Splitter.generate_execution_plan.<locals>.apply_split(node)
#     309 async def apply_split(node: Node):
# --> 310     nodes, relationships = await self.split(node)
#     311     kg.nodes.extend(nodes)
#     312     kg.relationships.extend(relationships)
#
# File c:\Users\Cengizhan\Desktop\CMPE492-Project-Rag-Pipeline\Code\venv_ragas\Lib\site-packages\ragas\testset\transforms\splitters\headline.py:65, in HeadlineSplitter.split(self, node)
#      63 headlines = node.get_property("headlines")
#      64 if headlines is None:
# ---> 65     raise ValueError("'headlines' property not found in this node")
#      67 if num_tokens_from_string(text) < self.min_tokens:
#      68     return [node], []
#
# ValueError: 'headlines' property not found in this node
